# %%
import pandas as pd
import geopandas as gpd
import matplotlib
import matplotlib.pyplot as plt
from geobr import read_state
import imageio
# %matplotlib inline

# %%
# Gerando shape do brasil dividido em estados com a biblioteca GEOBR
shape_br = read_state(code_state='all')
shape_br.plot()

# %%
# Seleciona em 'casos_full.csv' apenas os atributos que vamos trabalhar
data = pd.read_csv('caso_full.csv')
data = data[['epidemiological_week','last_available_confirmed','last_available_deaths', 'place_type', 'city_ibge_code','state']]

# %%
# Filtra todas informações de estados e agrupa por semana epidemiológica
data_state = data[data['place_type']=='state']
data_state = data_state.groupby(['epidemiological_week', 'state']).max()
data_state
# Out:
#                             last_available_confirmed  last_available_deaths  \
# epidemiological_week state
# 9                    SP                            2                      0
# 10                   BA                            2                      0
#                      DF                            1                      0
#                      ES                            1                      0
#                      RJ                            2                      0
# ...                                              ...                    ...
# 34                   RS                       103891                   2881
#                      SC                       126850                   1918
#                      SE                        69067                   1745
#                      SP                       721377                  27591
#                      TO                        39832                    536
#
#                            place_type  city_ibge_code
# epidemiological_week state
# 9                    SP         state            35.0
# 10                   BA         state            29.0
#                      DF         state            53.0
#                      ES         state            32.0
#                      RJ         state            33.0
# ...                               ...             ...
# 34                   RS         state            43.0
#                      SC         state            42.0
#                      SE         state            28.0
#                      SP         state            35.0
#                      TO         state            17.0
#
# [644 rows x 4 columns]

# %%
# Cria a coluna com o poligono representante de cada estado e adiciona ela ao data_state
states = shape_br[['code_state', 'geometry']]
data_state.reset_index(inplace=True)
data_state = data_state.merge(states,how='inner', left_on='city_ibge_code', right_on='code_state')
data_state = data_state.drop(['city_ibge_code','place_type'], axis=1)
data_state
# Out:
#      epidemiological_week state  last_available_confirmed  \
# 0                       9    SP                         2
# 1                      10    SP                        13
# 2                      11    SP                        65
# 3                      12    SP                       396
# 4                      13    SP                      1406
# ..                    ...   ...                       ...
# 639                    30    TO                     21767
# 640                    31    TO                     26434
# 641                    32    TO                     31663
# 642                    33    TO                     36989
# 643                    34    TO                     39832
#
#      last_available_deaths  code_state  \
# 0                        0        35.0
# 1                        0        35.0
# 2                        0        35.0
# 3                       15        35.0
# 4                       84        35.0
# ..                     ...         ...
# 639                    346        17.0
# 640                    395        17.0
# 641                    451        17.0
# 642                    511        17.0
# 643                    536        17.0
#
#                                               geometry
# 0    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...
# 1    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...
# 2    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...
# 3    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...
# 4    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...
# ..                                                 ...
# 639  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...
# 640  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...
# 641  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...
# 642  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...
# 643  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...
#
# [644 rows x 6 columns]

# %%
# Gera a Letalidade e cria uma coluna 
data_state['letalidade'] = (data_state['last_available_deaths']/data_state['last_available_confirmed'])*100
data_state
# Out:
#      epidemiological_week state  last_available_confirmed  \
# 0                       9    SP                         2
# 1                      10    SP                        13
# 2                      11    SP                        65
# 3                      12    SP                       396
# 4                      13    SP                      1406
# ..                    ...   ...                       ...
# 639                    30    TO                     21767
# 640                    31    TO                     26434
# 641                    32    TO                     31663
# 642                    33    TO                     36989
# 643                    34    TO                     39832
#
#      last_available_deaths  code_state  \
# 0                        0        35.0
# 1                        0        35.0
# 2                        0        35.0
# 3                       15        35.0
# 4                       84        35.0
# ..                     ...         ...
# 639                    346        17.0
# 640                    395        17.0
# 641                    451        17.0
# 642                    511        17.0
# 643                    536        17.0
#
#                                               geometry  letalidade
# 0    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...    0.000000
# 1    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...    0.000000
# 2    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...    0.000000
# 3    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...    3.787879
# 4    MULTIPOLYGON (((-44.90215 -23.35392, -44.90650...    5.974395
# ..                                                 ...         ...
# 639  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...    1.589562
# 640  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...    1.494288
# 641  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...    1.424375
# 642  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...    1.381492
# 643  MULTIPOLYGON (((-48.35878 -5.17008, -48.33846 ...    1.345652
#
# [644 rows x 7 columns]

# %%
#Faz a plotagem dos mapas por semana epidemiológica 
for semana in range(9,32):
    semana_x = data_state[data_state.epidemiological_week == semana]
    
    #Fazendo o typecasting para GeoDataFrame
    semana_x = gpd.GeoDataFrame(semana_x)
    copy = gpd.GeoDataFrame(data_state)
    copy2 = shape_br
    copy2['coords'] = copy2['geometry'].apply(lambda x: x.representative_point().coords[:])
    copy2['coords'] = [coords[0] for coords in copy2['coords']]
    
    fig, ax = plt.subplots(figsize=(20, 15))
    semana_x.plot(column='letalidade', cmap='gist_heat_r', vmin=0.0, legend=True,legend_kwds={'label': f"(Em %)", 'orientation': "vertical"},vmax=data_state['letalidade'].max(), ax=ax)
    
    ax.annotate(f'Semana {semana}', xy=(0.1,.225),xycoords='figure fraction',horizontalalignment='left', verticalalignment='top',fontsize=35)
    copy.geometry.boundary.plot(color=None,edgecolor='#888888',linewidth = 0.1,ax=ax)
    ax.set_title(f"Letalidade COVID-19 por Unidade da Federação (em %)", fontdict={'fontsize':25})
    ax.axis('off')
    
    for i, j in copy2.iterrows():
        plt.annotate(s=j[1], xy=j['coords'], horizontalalignment='center', verticalalignment='center', fontsize=20)
    #plt.show()
    # Salva cada mapa como um chart
    chart = ax.get_figure()
    chart.savefig(f'semana_{semana}_letalidade.png', dpi=120)
# Out:
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))
# <ipython-input-28-0b3e249646b6>:12: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(figsize=(20, 15))

# %%
data_state.columns = ['CD_GEOCUF', 'confirmed', 'deaths', 'death_rate']

# %%
df_geo = pd.merge(brasil, data_state, on='CD_GEOCUF')

# %%
df_geo.describe()
# Out:
#           confirmed         deaths  death_rate
# count  2.700000e+01      27.000000   27.000000
# mean   6.641540e+05   23410.037037    2.946139
# std    6.644939e+05   33013.628415    1.597608
# min    1.351540e+05    2515.000000    1.309601
# 25%    3.448300e+05    8138.500000    2.147686
# 50%    5.014370e+05   12260.000000    2.530650
# 75%    7.700990e+05   21782.500000    3.424525
# max    3.609762e+06  156673.000000    8.157219

# %%
gdf = gpd.GeoDataFrame(df_geo)

# %%
from mpl_toolkits.axes_grid1 import make_axes_locatable

fig, ax = plt.subplots(1, 1, figsize=(9, 9))
ax.set_facecolor('#ffffff')

divider = make_axes_locatable(ax)
cax = divider.append_axes("bottom", size="10%", pad=0.1)

cmap = matplotlib.colors.LinearSegmentedColormap.from_list("", ["#40e0d0", "#20c6b6", "#1a9e92", "#11655e"])

norm = matplotlib.colors.BoundaryNorm([0,2,4,6,8], cmap.N)

brasil.plot(ax=ax, facecolor='#d4d4d4', edgecolor='#ffffff', linewidth=0.4)

gdf.plot(column='death_rate', ax=ax, legend=True, cax=cax, cmap=cmap, edgecolor='#ffffff', linewidth=0.4,
        ,
         norm=norm)
